# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
products = pd.read_csv('producto_tabla.csv')

# %%
train = pd.read_csv('train.csv', usecols=['Producto_ID', 'Venta_hoy', 'Venta_uni_hoy'])
train['price'] = train['Venta_hoy']/train['Venta_uni_hoy']
tp = train[['Producto_ID', 'price']]

# %%
price = tp.groupby(['Producto_ID'])['price'].mean().reset_index()

# %%
products = pd.merge(products, price, how='left', on=['Producto_ID'])

# %%
products['short_name'] = products.NombreProducto.str.extract('^(\D*)', expand=False)
products['brand'] = products.NombreProducto.str.extract('^.+\s(\D+) \d+$', expand=False)
w = products.NombreProducto.str.extract('(\d+)(Kg|g)', expand=True)
products['weight'] = w[0].astype('float')*w[1].map({'Kg':1000, 'g':1})
products['pieces'] =  products.NombreProducto.str.extract('(\d+)p ', expand=False).astype('float')

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 1000) 

product_bag_words = vectorizer.fit_transform(products.short_name).toarray()
product_bag_words.shape
# Out:
# (2592L, 808L)

# %%
from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering

cltr = KMeans(n_clusters=100)
inds = cltr.fit_predict(product_bag_words)

# %%
products['short_name'].values[np.where(inds==0)]
# Out:
# array(['Tartinas Zarzamora ', 'Tartinas Zarzamora ', 'Tartinas Zarzamora ',
#        'Tartina Zarzamora ', 'Tartinas Zarzamora ', 'Tartinas Zarzamora ',
#        'Tartinas Zarzamora ', 'Tartinas Zarzamora ',
#        'Tartinas Zarzamora MG ', 'Tartinas Zarzamora '], dtype=object)

# %%
products['cluster_nombre'] = inds
products['drink'] = 0

# %%
price_na = {}
for row in products.iterrows():
    if np.isnan(row[1]['weight']):
        products.set_value(row[0], 'drink', 1)
    if np.isnan(row[1]['price']):
        cluster = products[products['cluster_nombre']==row[1]['cluster_nombre']]
        subcluster = cluster[cluster['brand']==row[1]['brand']]
        subsubcluster = cluster[cluster['weight']==row[1]['weight']]
        subsubmed =  subsubcluster['price'].median()
        submed =  subcluster['price'].median()
        med =  cluster['price'].median()
        if np.isnan(subsubmed):
            if np.isnan(submed):
                if np.isnan(med):
                    products.set_value(row[0], 'price', 0)
                else:
                    products.set_value(row[0], 'price', med)
            else:
                products.set_value(row[0], 'price', submed)
        else:
            products.set_value(row[0], 'price', subsubmed)

# %%
products['pieces'].fillna(1, inplace=True)
products['w_per_piece'] = products['weight']/products['pieces']
products.fillna(0, inplace=True)

# %%
products.to_csv('products.csv')

# %%
productss = pd.read_csv('products.csv')

# %%
products
# Out:
#       Producto_ID                                  NombreProducto       price  \
# 0               9                       Capuccino Moka 750g NES 9   82.500000
# 1              41          Bimbollos Ext sAjonjoli 6p 480g BIM 41   17.992632
# 2              53                  Burritos Sincro 170g CU LON 53   14.300088
# 3              72             Div Tira Mini Doradita 4p 45g TR 72    3.697305
# 4              73               Pan Multigrano Linaza 540g BIM 73   21.360519
# 2580        49972    Pan Blanco Bimbo Rendidor 567g MTA BIM 49972   16.596484
# 2581        49973        Pan Blanco Bimbo Rendidor 567g BIM 49973   16.591863
# 2582        49986                   Tostado Blanco 180g WON 49986   13.899312
# 2583        49988               Tostado Blanco 180g MTA WON 49988   13.921232
# 2584        49989               Tostado Blanco 180g TAB WON 49989   15.206667
# 2585        49990                 Tostado Integral 180g WON 49990   14.924778
# 2586        49992             Tostado Integral 180g MTA WON 49992   15.182422
# 2587        49993             Tostado Integral 180g TAB WON 49993   16.200000
# 2588        49994      Tostado Int 0pct Grasa Azuc 200g WON 49994   14.742101
# 2589        49996  Tostado Int 0pct Grasa Azuc 200g MTA WON 49996   14.524167
# 2590        49997  Tostado Int 0pct Grasa Azuc 200g TAB WON 49997   16.200000
#
#                       short_name brand   weight  pieces  cluster_nombre  \
# 0                Capuccino Moka    NES    750.0     1.0              93
# 1       Bimbollos Ext sAjonjoli    BIM    480.0     6.0              62
# 2               Burritos Sincro    LON    170.0     1.0              93
# 3        Div Tira Mini Doradita     TR     45.0     4.0              44
# 4         Pan Multigrano Linaza    BIM    540.0     1.0              75
# 5              Tostado Integral    WON    180.0     1.0              56
# 6                    Pan Blanco    WON    567.0     1.0              26
# 7        Super Pan Bco Ajonjoli    WON    680.0     1.0               2
# 8                        Wonder    WON    475.0     1.0              28
# 9                        Wonder    WON    680.0     1.0              28
# 10      Baguette Precocida Cong     DH    280.0     1.0              93
# 11              Pan Multicereal    WON    475.0     1.0               2
# 12             Tostado Integral    WON    180.0     1.0              56
# 13     Biscotel Receta Original    SUA    410.0     1.0              93
# 14                 Super Bollos    WON    540.0     8.0              23
# 15                       Bollos    WON    450.0     8.0              37
# 16                    Bollos BK     SL   1635.0    36.0              37
# 17                    Bollos BK     SL   1730.0    30.0              37
# 18                    Bollos BK     SL   1635.0    30.0              37
# 19                    Bollos BK     SL   1730.0    20.0              37
# 20                     Hot Dogs    WON    290.0     8.0              97
# 21               Super Hot Dogs    WON    435.0     8.0              97
# 22                Medias Noches     SL    470.0    24.0               3
# 23                     Bollo WB     SL   1950.0    20.0              93
# 24                 Molido Bolsa    WON    180.0     1.0              93
# 25                   Bollos KFC    WON   1237.0    15.0              37
# 26                       Molido    WON  25000.0     1.0              93
# 27                       Molido    WON   5000.0     1.0              93
# 28                  Tostado Int    WON    200.0     1.0              33
# 29             Tortillas Harina    WON    260.0    10.0              94
# ...                          ...   ...      ...     ...             ...
# 2561             Powerade Limon     CC      0.0     1.0              93
# 2562              Powerade Mora     CC      0.0     1.0              93
# 2563           Powerade Naranja     CC      0.0     1.0              93
# 2564               Powerade Uva     CC      0.0     1.0              93
# 2565           Totopos Redondos     DH    250.0     1.0              84
# 2566                 Fanta Lata     CC      0.0     1.0              73
# 2567           Sprite Zero Lata     CC      0.0     1.0              73
# 2568         Sidral Mundet Lata     CC      0.0     1.0              73
# 2569     Bombonete San Valentin    MLA     55.0     3.0              93
# 2570                Tortillinas     TR    570.0    22.0              13
# 2571                Tortillinas     TR    310.0    12.0              13
# 2572                Tortillinas     TR    310.0    12.0              13
# 2573         Totopo Chilaquiles     MR    500.0     1.0              35
# 2574      Bimkingo Clasico Prom    LON    135.0     1.0              81
# 2575                 Gansito ME    MLA    250.0     5.0              16
# 2576                     Wonder    WON    475.0     1.0              28
# 2577                    Conchas     TR    180.0     3.0              93
# 2578                       Dona    BIM     26.0     1.0              93
# 2579  Pan Blanco Bimbo Rendidor    BIM    567.0     1.0              26
# 2580  Pan Blanco Bimbo Rendidor    BIM    567.0     1.0              26
# 2581  Pan Blanco Bimbo Rendidor    BIM    567.0     1.0              26
# 2582             Tostado Blanco    WON    180.0     1.0              33
# 2583             Tostado Blanco    WON    180.0     1.0              33
# 2584             Tostado Blanco    WON    180.0     1.0              33
# 2585           Tostado Integral    WON    180.0     1.0              56
# 2586           Tostado Integral    WON    180.0     1.0              56
# 2587           Tostado Integral    WON    180.0     1.0              56
# 2588                Tostado Int    WON    200.0     1.0              33
# 2589                Tostado Int    WON    200.0     1.0              33
# 2590                Tostado Int    WON    200.0     1.0              33
#
#       drink   w_per_piece
# 0         0    750.000000
# 1         0     80.000000
# 2         0    170.000000
# 3         0     11.250000
# 4         0    540.000000
# 5         0    180.000000
# 6         0    567.000000
# 7         0    680.000000
# 8         0    475.000000
# 9         0    680.000000
# 10        0    280.000000
# 11        0    475.000000
# 12        0    180.000000
# 13        0    410.000000
# 14        0     67.500000
# 15        0     56.250000
# 16        0     45.416667
# 17        0     57.666667
# 18        0     54.500000
# 19        0     86.500000
# 20        0     36.250000
# 21        0     54.375000
# 22        0     19.583333
# 23        0     97.500000
# 24        0    180.000000
# 25        0     82.466667
# 26        0  25000.000000
# 27        0   5000.000000
# 28        0    200.000000
# 29        0     26.000000
# ...     ...           ...
# 2561      1      0.000000
# 2562      1      0.000000
# 2563      1      0.000000
# 2564      1      0.000000
# 2565      0    250.000000
# 2566      1      0.000000
# 2567      1      0.000000
# 2568      1      0.000000
# 2569      0     18.333333
# 2570      0     25.909091
# 2571      0     25.833333
# 2572      0     25.833333
# 2573      0    500.000000
# 2574      0    135.000000
# 2575      0     50.000000
# 2576      0    475.000000
# 2577      0     60.000000
# 2578      0     26.000000
# 2579      0    567.000000
# 2580      0    567.000000
# 2581      0    567.000000
# 2582      0    180.000000
# 2583      0    180.000000
# 2584      0    180.000000
# 2585      0    180.000000
# 2586      0    180.000000
# 2587      0    180.000000
# 2588      0    200.000000
# 2589      0    200.000000
# 2590      0    200.000000
#
# [2591 rows x 10 columns]
